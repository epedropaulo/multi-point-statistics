# %%
import mpslib as mps
import matplotlib.pyplot as plt

# %%
import pyvista as pv
print(hasattr(pv, 'UniformGrid'))
# Out:
# False

# %%
O.par
# Out:
# {'n_real': 4,
#  'rseed': 1,
#  'n_max_cpdf_count': 1,
#  'out_folder': '.',
#  'ti_fnam': 'ti.dat',
#  'simulation_grid_size': array([40, 20,  1]),
#  'origin': array([0., 0., 0.]),
#  'grid_cell_size': array([1, 1, 1]),
#  'mask_fnam': 'mask.dat',
#  'hard_data_fnam': 'hard.dat',
#  'shuffle_simulation_grid': 2,
#  'entropyfactor_simulation_grid': 4,
#  'shuffle_ti_grid': 1,
#  'hard_data_search_radius': 1,
#  'soft_data_categories': array([0, 1]),
#  'soft_data_fnam': 'soft.dat',
#  'n_threads': -1,
#  'debug_level': -1,
#  'do_estimation': 0,
#  'do_entropy': 0,
#  'template_size': array([8, 7, 1]),
#  'n_multiple_grids': 3,
#  'n_min_node_count': 0,
#  'n_cond': 16}

# %%
O = mps.mpslib(method='mps_snesim_tree')
O.par['n_real'] = 4
O.ti = mps.trainingimages.strebelle()[0]
O.run()
# Out:
# Using mps_snesim_tree installed in c:\Users\leoyv\AppData\Local\Programs\Python\Python312\Lib\site-packages\mpslib\bin (scikit-mps in c:\Users\leoyv\AppData\Local\Programs\Python\Python312\Lib\site-packages\mpslib\mpslib.py)
# True

# %%
O.plot_reals()

# %%
O.plot_etype()

# %%
plt.imshow(mps.trainingimages.strebelle()[0])

# %%
O.ti = mps.trainingimages.strebelle()[0]
O.plot_ti()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 2
#       1 O.ti = mps.trainingimages.strebelle()[0]
# ----> 2 O.plot_ti()
#
# File c:\Users\leoyv\AppData\Local\Programs\Python\Python312\Lib\site-packages\mpslib\mpslib.py:1009, in mpslib.plot_ti(self)
#    1006         return -1
#    1008 if hasattr(self,'ti'):
# -> 1009     plot.plot(self.ti, title="Training image - %s" % (self.par['ti_fnam']), slice=1   )
#    1010 else:
#    1011     print('Could not plot TI')
#
# File c:\Users\leoyv\AppData\Local\Programs\Python\Python312\Lib\site-packages\mpslib\plot.py:70, in plot(D, force_3d, slice, threshold, origin, spacing, **kwargs)
#      67 cmap = kwargs.get('cmap',"viridis")
#      69 if (D.ndim == 3)|(force_3d==1):
# ---> 70     plot_3d(D, origin=origin, spacing=spacing, **kwargs)
#      71 else:
#      72     plot_2d(D, origin=origin, spacing=spacing, **kwargs)
#
# File c:\Users\leoyv\AppData\Local\Programs\Python\Python312\Lib\site-packages\mpslib\plot.py:142, in plot_3d(Data, origin, spacing, **kwargs)
#     140 # create uniform grid
#     141 if (plotgrid==1)|(slice==1):
# --> 142     grid = numpy_to_pvgrid(Data, origin=origin, spacing=spacing)
#     144 if (plotgrid==1)&(slice==0):
#     145     plot.add_mesh(grid, cmap=cmap, show_edges=show_edges, opacity=opacity)
#
# File c:\Users\leoyv\AppData\Local\Programs\Python\Python312\Lib\site-packages\mpslib\plot.py:42, in numpy_to_pvgrid(Data, origin, spacing)
#      36 '''
#      37 Convert 3D numpy array to pyvista uniform grid
#      38
#      39 '''
#      41 # Create the spatial reference
# ---> 42 grid = pyvista.UniformGrid()
#      43 # Set the grid dimensions: shape + 1 because we want to inject our values on the CELL data
#      44 grid.dimensions = np.array(Data.shape) + 1
#
# File c:\Users\leoyv\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyvista\__init__.py:113, in __getattr__(name)
#     111     feature = inspect.getattr_static(sys.modules['pyvista.plotting'], name)
#     112 except AttributeError:
# --> 113     raise AttributeError(f"module 'pyvista' has no attribute '{name}'") from None
#     115 return feature
#
# AttributeError: module 'pyvista' has no attribute 'UniformGrid'
